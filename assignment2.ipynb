# %%
import glob
import math
import nltk
import numpy as np
import os
import re
import string
from pathlib import Path

# %% [markdown]
# # 1. Text Classification using Naive Bayes

# %% [markdown]
# ## 1.1 Build a Naive Bayes Classifier

# %%
# Get the paths of all the class sub-directories in the Training Data directory
training_data_directories = [directory.path for directory in os.scandir(os.path.join(os.getcwd(), 'Reuters Training Data')) if directory.is_dir()]

# %%
# For each class, get the paths of all training files
training_data_files = {}

for directory in training_data_directories:
    class_name = directory.rsplit('\\', 1)[1]
    file_names = glob.glob(os.path.join(directory, '*'))
    training_data_files[class_name] = [file_name for file_name in file_names]

# %%
def textFormatter(file_path):
    """
    Remove all newlines and duplicate spaces from the text in the file corresponding
    to the specified file path, and convert all characters to lower case.
    """
    formatted_text = ''
    
    with open(file_path, 'r') as text:
        print(file_path)
        formatted_text = ' '.join([line.strip() for line in text.read().split('\n') if line.strip])
    
    formatted_text = re.sub(' +', ' ', formatted_text)
    
    return formatted_text.lower()

# %%
class NaiveBayesMB:
    """
    Multinomial Naive Bayes classifier that works with text data.
    """
    def __init__(self):
        self.classes_ = []
        self.log_priors_ = {}
        self.log_likelihoods_ = {}
        self.vocabulary_ = []
        self.vocabulary_size_ = 0
    
    def fit(self, X, y):
        """
        Compute log likelihood and log prior values from the specified X and y lists,
        where X is a list of (pre-processed) texts and y is a list of class labels.
        """
        self.classes_ = set(y)
        total_document_count = len(X)
        training_class_word_counts = NaiveBayesMB.trainClassWordCounts(X, y)
        self.createVocabulary(training_class_word_counts)
        
        for train_class in training_class_word_counts.keys():
            log_prior = math.log2(y.count(train_class) / total_document_count)
            self.log_priors_[train_class] = log_prior
            self.log_likelihoods_[train_class] = {}
            for word in self.vocabulary_:
                # Use Laplace add-1 smoothing
                word_count = 0 if word not in training_class_word_counts[train_class] else training_class_word_counts[train_class][word]
                smoothed_class_word_count = word_count + 1
                smoothed_class_vocabulary_count = len(training_class_word_counts[train_class]) + self.vocabulary_size_
                log_likelihood = math.log2(smoothed_class_word_count / smoothed_class_vocabulary_count)
                self.log_likelihoods_[train_class][word] = log_likelihood
                
    def predict(self, X):
        """
        Perform classification on a list of texts.
        """
        predictions = []
        
        for text in X:
            sums = {}
            probs = {}
            for train_class in self.classes_:
                sums[train_class] = self.log_priors_[train_class]
                tokenized_text = NaiveBayesMB.textTokenizer(text)
                for word in tokenized_text:
                    if word in self.vocabulary_:
                        log_likelihood = 0 if word not in self.log_likelihoods_[train_class] else self.log_likelihoods_[train_class][word]
                        sums[train_class] = sums[train_class] + log_likelihood
                probs[train_class] = 2**sums[train_class]
            predicted_class = max(probs, key=probs.get)
            predictions.append(predicted_class)
            
        return predictions
    
    def createVocabulary(self, class_word_counts):
        """
        Generate a vocabulary of all unique words in all of the input texts.
        """
        for train_class in class_word_counts.keys():
            for word in class_word_counts[train_class].keys():
                if not word in self.vocabulary_:
                    self.vocabulary_.append(word)
        
        self.vocabulary_size_ = len(self.vocabulary_)
    
    def trainClassDocumentUniqueWords(X, y):
        """
        Return a dictionary of unique words for each document in each
        class.
        """
        training_class_document_unique_words = {}
        
        for index, text in enumerate(X):
            train_class = y[index]
            if not train_class in training_class_document_unique_words.keys():
                training_class_document_unique_words[train_class] = {}
            tokenized_text = NaiveBayesMB.textTokenizer(text)
            unique_words = list(set(tokenized_text))
            training_class_document_unique_words[train_class][index] = unique_words
            
        return training_class_document_unique_words
    
    def trainClassWordCounts(X, y):
        """
        Return the counts for each unique word that occurs in each class.
        The counts refer to the number of documents each word occurs in.
        """
        training_class_word_counts = {}
        training_class_document_unique_words = NaiveBayesMB.trainClassDocumentUniqueWords(X, y)
        
        for train_class in training_class_document_unique_words.keys():
            training_class_word_counts[train_class] = {}
            for file_name in training_class_document_unique_words[train_class]:
                for word in training_class_document_unique_words[train_class][file_name]:
                    if not word in training_class_word_counts[train_class].keys():
                        training_class_word_counts[train_class][word] = 1
                    else:
                        training_class_word_counts[train_class][word] = training_class_word_counts[train_class][word] + 1
        
        return training_class_word_counts
    
    def textTokenizer(text):
        """
        Tokenize and return the specified text into a list of words.
        """
        non_alpha_numeric_matcher = re.compile('\W')
        tokens = nltk.word_tokenize(text)
        tokens = [token for token in tokens if non_alpha_numeric_matcher.match(token) == None]
        
        return tokens

# %%
# Create list of 'earn' class file names
earn_class_files_names = []

for file in training_data_files['earn']:
    file_name = file.rsplit('\\', 1)[1]
    earn_class_files_names.append(file_name)

# %%
# Create inputs for Multinomial Naive Bayes model
input_texts = []
classes = []

for train_class in training_data_files.keys():
    for file in training_data_files[train_class]:
        file_name = file.rsplit('\\', 1)[1]
        class_name = 'earn' if file_name in earn_class_files_names else 'not_earn'
        formatted_text = textFormatter(file)
        input_texts.append(formatted_text)
        classes.append(class_name)

# %%
# Create the Multinomial Naive Bayes classifier and fit to the training data
naive_bayes_MB = NaiveBayesMB()
naive_bayes_MB.fit(input_texts, classes)

# %%
# Run the Multinomial Naive Bayes classifier on the training data 
train_predictions = naive_bayes_MB.predict(input_texts)

# %% [markdown]
# ## 1.2 Implement the Evaluation Metrics

# %%
class EvaluationMetrics:
    """
    Calculate precision, recall, and F1 Measure for a list of classes, a list of
    predictions, and a target category.
    """
    def __init__(self, classes, predictions, target):
        self.classes_ = classes
        self.predictions_ = predictions
        self.target_ = target
        
    def precision(self):
        """
        Calculate the precision.
        """
        true_positives = 0
        false_positives = 0
        
        for index,prediction in enumerate(self.predictions_):
            if self.classes_[index] == self.target_ and prediction == self.target_:
                true_positives = true_positives + 1
            elif self.classes_[index] != self.target_ and prediction == self.target_:
                false_positives = false_positives + 1
                
        precision = true_positives / (true_positives + false_positives)
        
        return precision
    
    def recall(self):
        """
        Calculate the recall.
        """
        true_positives = 0
        false_negatives = 0
        
        for index,prediction in enumerate(self.predictions_):
            if self.classes_[index] == self.target_ and prediction == self.target_:
                true_positives = true_positives + 1
            if self.classes_[index] == self.target_ and prediction != self.target_:
                false_negatives = false_negatives + 1
                
        recall = true_positives / (true_positives + false_negatives)
        
        return recall
    
    def F1(self):
        """
        Calculate F1 Measure.
        """
        precision = self.precision()
        recall = self.recall()
        
        f1 = (2 * precision * recall) / (precision + recall)
        
        return f1
    
    def printSummary(self):
        """
        Print a summary of the precision, recall, and F1 Measure scores.
        """
        precision = self.precision()
        recall = self.recall()
        f1 = self.F1()
        
        print("precision: {}".format(precision))
        print("recall: {}".format(recall))
        print("f1: {}".format(f1))

# %%
# Calculate precision, recall, and F1 measure for the training predictions and print a summary
metrics = EvaluationMetrics(classes, train_predictions, 'earn')
metrics.printSummary()
# Out:
# precision: 0.9995194617972128
# recall: 0.7155142758857929
# f1: 0.834001603849238

# %% [markdown]
# ## 1.3 Run the Classifier on Test Set

# %%
# Load in the test data
test_files = glob.glob(os.path.join(os.getcwd(), 'Reuters Test Data', '*'))
test_texts = [textFormatter(file) for file in test_files]
# Out:
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009603
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009604
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009605
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009606
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009609
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009611
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009613
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009616
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009618
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009622
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009623
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009624
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009625
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009626
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009628
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009633
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009634
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009635
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009636
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009638
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009643
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009645
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009652
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009653
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009656
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009657
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009658
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009659
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009660
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009661
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009662
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009664
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009666
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009669
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009673
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009674
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009675
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009676
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009677
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009678
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009679
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009680
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009683
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009684
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009685
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009686
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009687
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009688
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009689
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009690
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009691
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009692
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009693
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009694
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009695
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009696
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009698
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009699
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009700
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009701
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009702
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009703
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009704
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009706
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009710
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009711
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009712
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009713
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009714
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009715
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009716
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009717
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009718
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009719
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009720
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009722
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009725
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009728
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009729
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009731
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009732
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009733
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009734
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009735
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009736
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009737
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009738
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009742
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009744
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009746
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009747
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009748
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009749
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009751
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009752
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009754
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009755
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009756
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009757
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009758
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009759
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009760
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009761
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009762
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009763
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009764
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009765
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009766
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009768
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009769
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009770
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009771
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009772
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009774
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009775
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009777
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009778
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009780
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009781
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009783
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009784
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009785
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009789
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009790
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009791
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009792
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009793
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009794
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009795
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009797
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009799
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009800
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009801
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009802
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009804
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009806
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009807
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009808
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009809
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009810
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009811
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009812
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009814
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009815
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009817
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009818
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009822
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009823
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009824
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009828
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009829
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009830
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009831
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009832
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009834
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009835
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009836
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009838
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009839
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009840
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009842
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009843
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009844
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009845
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009846
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009847
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009848
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009851
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009852
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009853
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009854
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009855
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009856
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009857
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009858
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009860
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009861
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009862
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009864
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009865
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009867
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009869
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009870
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009872
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009873
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009874
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009875
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009876
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009878
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009879
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009880
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009881
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009882
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009883
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009884
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009885
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009886
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009887
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009888
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009892
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009894
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009895
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009896
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009897
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009898
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009899
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009900
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009901
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009902
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009903
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009904
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009905
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009906
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009907
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009908
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009909
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009910
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009912
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009913
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009914
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009915
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009916
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009917
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009921
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009922
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009923
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009924
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009926
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009927
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009928
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009930
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009931
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009932
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009933
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009934
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009935
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009938
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009940
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009941
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009943
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009944
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009947
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009948
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009950
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009951
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009952
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009953
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009954
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009956
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009957
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009958
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009959
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009960
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009965
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009966
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009972
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009973
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009976
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009979
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009983
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009987
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009990
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009992
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009993
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009994
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009995
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009996
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0009999
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010000
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010003
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010004
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010007
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010008
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010009
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010010
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010011
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010012
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010013
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010016
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010018
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010019
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010021
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010024
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010025
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010027
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010028
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010029
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010030
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010031
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010033
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010035
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010037
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010039
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010043
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010044
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010045
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010047
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010048
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010055
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010056
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010058
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010061
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010062
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010063
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010064
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010067
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010068
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010069
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010071
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010073
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010076
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010078
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010079
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010081
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010082
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010084
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010086
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010087
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010090
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010091
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010092
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010093
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010096
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010097
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010098
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010100
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010101
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010102
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010103
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010106
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010108
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010109
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010110
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010111
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010112
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010113
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010115
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010118
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010119
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010120
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010121
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010122
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010123
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010124
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010125
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010127
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010128
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010129
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010130
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010131
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010134
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010137
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010138
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010139
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010140
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010141
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010144
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010148
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010149
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010151
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010153
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010154
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010156
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010157
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010160
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010161
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010164
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010165
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010166
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010167
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010170
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010171
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010172
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010174
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010175
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010176
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010177
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010178
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010180
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010182
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010183
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010184
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010185
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010187
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010188
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010189
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010190
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010191
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010192
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010193
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010194
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010195
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010196
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010197
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010198
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010199
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010200
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010201
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010202
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010203
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010205
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010206
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010207
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010208
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010209
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010211
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010212
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010213
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010214
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010215
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010216
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010217
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010218
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010219
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010220
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010221
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010226
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010228
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010229
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010230
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010232
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010236
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010237
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010238
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010239
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010240
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010241
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010242
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010244
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010246
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010248
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010249
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010252
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010253
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010254
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010256
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010259
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010261
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010262
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010263
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010264
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010269
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010270
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010271
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010273
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010275
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010276
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010277
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010278
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010279
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010284
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010285
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010286
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010289
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010292
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010293
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010294
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010295
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010297
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010298
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010299
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010300
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010301
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010302
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010304
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010305
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010307
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010308
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010309
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010310
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010312
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010313
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010314
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010315
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010316
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010317
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010318
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010319
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010320
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010321
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010322
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010323
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010324
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010325
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010326
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010327
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010329
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010331
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010332
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010333
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010334
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010335
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010336
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010337
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010338
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010339
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010340
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010341
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010342
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010349
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010350
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010352
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010354
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010355
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010356
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010357
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010359
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010360
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010364
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010366
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010367
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010369
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010370
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010371
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010372
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010373
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010374
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010375
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010377
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010381
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010382
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010383
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010384
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010385
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010391
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010392
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010394
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010395
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010396
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010397
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010398
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010399
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010400
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010401
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010402
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010403
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010404
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010405
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010406
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010407
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010408
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010409
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010410
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010411
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010413
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010414
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010415
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010416
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010417
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010418
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010419
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010420
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010421
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010423
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010427
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010428
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010429
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010430
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010431
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010432
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010433
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010434
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010435
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010436
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010437
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010439
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010440
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010441
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010442
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010444
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010445
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010446
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010449
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010452
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010456
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010457
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010460
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010461
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010462
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010463
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010468
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010469
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010473
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010475
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010478
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010480
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010481
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010482
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010484
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010485
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010486
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0010488
# ...
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012684
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012685
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012686
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012687
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012689
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012690
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012691
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012692
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012693
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012694
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012695
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012696
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012697
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012698
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012699
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012700
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012701
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012702
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012703
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012704
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012705
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012706
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012707
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012708
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012709
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012710
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012711
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012712
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012713
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012714
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012716
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012717
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012718
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012719
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012720
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012721
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012722
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012723
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012724
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012725
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012726
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012727
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012728
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012729
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012730
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012731
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012732
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012733
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012734
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012735
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012736
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012737
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012738
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012739
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012740
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012741
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012742
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012743
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012744
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012746
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012747
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012748
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012749
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012750
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012751
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012752
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012753
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012754
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012756
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012757
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012758
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012760
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012761
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012762
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012763
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012764
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012765
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012766
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012767
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012768
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012769
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012770
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012771
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012772
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012773
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012774
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012775
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012776
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012777
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012778
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012779
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012780
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012781
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012782
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012784
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012785
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012786
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012787
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012788
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012789
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012790
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012791
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012792
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012793
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012794
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012795
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012796
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012797
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012798
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012799
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012800
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012801
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012802
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012804
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012805
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012806
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012807
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012808
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012809
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012810
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012811
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012812
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012813
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012814
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012815
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012816
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012817
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012818
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012820
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012821
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012822
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012823
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012824
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012825
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012826
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012827
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012828
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012829
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012830
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012831
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012833
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012834
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012835
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012836
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012837
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012838
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012839
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012840
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012841
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012842
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012843
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012845
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012846
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012847
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012848
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012849
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012850
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012851
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012852
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012853
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012854
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012855
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012856
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012857
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012858
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012859
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012860
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012862
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012863
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012864
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012865
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012866
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012867
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012868
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012869
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012870
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012872
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012873
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012875
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012876
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012878
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012880
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012881
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012882
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012883
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012885
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012886
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012887
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012888
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012889
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012891
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012892
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012895
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012896
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012897
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012898
# D:\School\NLP\Class Repo\CS-6120_saulniern\Assignment2\Reuters Test Data\0012899

# %%
# Run the classifier on the test set
test_predictions = naive_bayes_MB.predict(test_texts)

# %%
# Get the list of files classified as 'earn'
test_earn_files = []

for index,prediction in enumerate(test_predictions):
    if prediction == 'earn':
        file_name = test_files[index].rsplit('\\', 1)[1]
        test_earn_files.append(file_name)

# %%
# Print the file names of test files classified as 'earn' to an output file
test_predictions_out = os.path.join(os.getcwd(), 'Naive Bayes Classifier Output', 'files_classified_as_earn.txt')

with open(test_predictions_out, 'w') as file:
    for file_name in test_earn_files:
        line = file_name + '\n'
        file.write(line)

# %% [markdown]
# # 2. Part-of-Speech (POS) Tagging using Hidden Markov Models (HMM)

# %% [markdown]
# ## 2.1 Frequency Counts

# %%
def writeDictionaryToFile(dictionary, out_file):
    """
    Write the specified dictionary to the specified output file.
    """
    with open(out_file, 'w') as file:
        for key in dictionary.keys():
            line = str(key) + ' : ' + str(dictionary[key]) + '\n'
            file.write(line)

# %%
# Get all Brown Corpus training file names
brown_corpus_train_files = glob.glob(os.path.join(os.path.join(os.getcwd(), 'Brown Corpus Training Data'), '*'))

# %%
# Create a string containing the formatted text from all Brown Corpus training files
training_file_texts = []

for file in brown_corpus_train_files:
    formatted_text = textFormatter(file)
    training_file_texts.append(formatted_text)

brown_corpus_train_text = ' '.join(training_file_texts)

# %%
sentence_begin = '<s>'
sentence_end = '<EOS>'

# %%
# Create a regex for parsing word/tag pairs
word_tag_pair_regex_string = '\s?(([^\s]+)\/([^\s]+))\s{1}'
word_tag_pair_regex = re.compile(word_tag_pair_regex_string)

# %%
# Extract all word/tag pairs in the Brown Corpus training text
word_tag_pairs = [(match.group(2),match.group(3)) for match in word_tag_pair_regex.finditer(brown_corpus_train_text)]

# %%
# Insert sentence end markers
sentence_end_insertions = []

end_count = 0
for index, pair in enumerate(word_tag_pairs):
    if pair[0] == '.' and pair[1] == '.':
        sentence_end_insertions.append(index + end_count)
        end_count += 1
    
for index in sentence_end_insertions:
    word_tag_pairs.insert(index, (sentence_end, sentence_end))

# %%
# Remove all punctuation pairs
word_tag_pairs = [pair for pair in word_tag_pairs if (not any(punct in pair[0][0] for punct in string.punctuation)) or pair[0] == sentence_end]

# %%
# Insert sentence begin markers
sentence_begin_insertions = []

begin_count = 1
sentence_begin_insertions.append(0)
for index, pair in enumerate(word_tag_pairs):
    if pair[0] == sentence_end and pair[1] == sentence_end:
        sentence_begin_insertions.append((begin_count + index) + 1)
        begin_count += 1
        
for index in sentence_begin_insertions:
    word_tag_pairs.insert(index, (sentence_begin, sentence_begin))

# %%
# Count word-tag pair occurrences
word_tag_pair_counts = {}

for pair in word_tag_pairs:
    if pair[0] != sentence_begin and pair[0] != sentence_end:
        if pair in word_tag_pair_counts:
            word_tag_pair_counts[pair] += 1
        else:
            word_tag_pair_counts[pair] = 1

# %%
# Count tag unigram occurrences
tag_unigram_counts = {}

for pair in word_tag_pairs:
    tag = pair[1]
    if tag in tag_unigram_counts:
        tag_unigram_counts[tag] += 1
    else:
        tag_unigram_counts[tag] = 1

# %%
# Count tag bigram occurences
tag_bigram_counts = {}

for index in range(1, len(word_tag_pairs) - 1):
    tag1 = word_tag_pairs[index - 1][1]
    tag2 = word_tag_pairs[index][1]
    tag_bigram = (tag1, tag2)
    if tag_bigram in tag_bigram_counts:
        tag_bigram_counts[tag_bigram] += 1
    else:
        tag_bigram_counts[tag_bigram] = 1

# %%
# Sort the count dictionarys in decreasing order by occurrence
word_tag_pair_counts = {word:count for word,count in sorted(word_tag_pair_counts.items(), key=lambda item: item[1], reverse=True)}
tag_unigram_counts = {unigram:count for unigram,count in sorted(tag_unigram_counts.items(), key=lambda item: item[1], reverse=True)}
tag_bigram_counts = {bigram:count for bigram,count in sorted(tag_bigram_counts.items(), key=lambda item: item[1], reverse=True)}

# %%
# Write the word/tag pair, tag/unigram, and tag/bigram counts to output files
word_tag_pair_out = os.path.join(os.getcwd(), 'Brown Corpus Training Data Counts Output', 'word_tag_pair_counts.txt')
tag_unigram_out = os.path.join(os.getcwd(), 'Brown Corpus Training Data Counts Output', 'tag_unigram_counts.txt')
tag_bigram_out = os.path.join(os.getcwd(), 'Brown Corpus Training Data Counts Output', 'tag_bigram_counts.txt')

writeDictionaryToFile(word_tag_pair_counts, word_tag_pair_out)
writeDictionaryToFile(tag_unigram_counts, tag_unigram_out)
writeDictionaryToFile(tag_bigram_counts, tag_bigram_out)

# %% [markdown]
# ## 2.2 Transition Probabilities

# %%
# Calculate transition probabilities for each possibile bigram
transition_probabilities = {}

for tag_unigram_1 in tag_unigram_counts.keys():
    for tag_unigram_2 in tag_unigram_counts.keys():
        tag_bigram = (tag_unigram_1, tag_unigram_2)
        bigram_count = 0 if not tag_bigram in tag_bigram_counts.keys() else tag_bigram_counts[tag_bigram]
        transition_probability = bigram_count / tag_unigram_counts[tag_unigram_1]
        transition_probabilities[tag_bigram] = transition_probability

# %% [markdown]
# ## 2.3 Emission Probabilities

# %%
# Get the list of unique words in the training data
unique_words = list(set([pair[0] for pair in word_tag_pair_counts.keys()]))

# %%
# Calculate the emission probability for each possible word/tag pair
emission_probabilities = {}

for word in unique_words:
    for tag in tag_unigram_counts.keys():
        word_tag_pair = (word, tag)
        word_tag_count = 0 if not word_tag_pair in word_tag_pair_counts else word_tag_pair_counts[word_tag_pair]
        emission_probability = word_tag_count / tag_unigram_counts[tag]
        emission_probabilities[word_tag_pair] = emission_probability

# %% [markdown]
# ## 2.4 Viterbi Algorithm

# %%
def cleanBrownTestSentence(sentence):
    """
    Remove punctuation from the tokenized sentence and return as a string with all tokens
    separated with a single space.
    """
    lines = sentence.split()
    lines = [line.lower() for line in lines if (not all([char in string.punctuation for char in line]))]
    return ' '.join(lines)

# %%
# Read the Brown Corpus tokenized test data file
brown_corpus_test_text = Path(os.path.join(os.getcwd(), 'Brown Corpus Test Data', 'BrownCorpusTokenizedDataTest_File.txt')).read_text()
brown_corpus_test_text_lines = brown_corpus_test_text.splitlines()

# %%
# Get the indexes for sentence start and sentence end tags
sentence_start_indexes = []
sentence_end_indexes = []
sentence_start_substring = '< sentence ID'
sentence_end_string = '<EOS>'

for index,line in enumerate(brown_corpus_test_text_lines):
    if sentence_start_substring in line:
        sentence_start_indexes.append(index)
    elif line == sentence_end_string:
        sentence_end_indexes.append(index)

# %%
# Parse and clean the test data sentences
test_data_sentences = {}
sentence_id_regex = re.compile('(\d+)')

for index in range(0, len(sentence_start_indexes)):
    sentence_start_index = sentence_start_indexes[index]
    sentence_end_index = sentence_end_indexes[index]
    sentence_tokens = brown_corpus_test_text_lines[sentence_start_index:sentence_end_index]
    sentence_tokens.insert(1, sentence_begin)
    sentence_tokens.insert(len(sentence_tokens) - 1, sentence_end)
    sentence_id = int(re.search(sentence_id_regex, sentence_tokens[0]).group(0))
    test_data_sentences[sentence_id] = cleanBrownTestSentence(' '.join(sentence_tokens[1:-1]))

# %%
def maxState(word_state_matrix, current_state, transition_probabilities, emission_probability):
    """
    Find and return the max previous state and the probability of the max state occurring before 
    the previous state given the emission probability of the current state and the current word.
    
    Inputs:
        word_state_matrix: matrix of probability values for all states for an observation. the
            probability values represent the maximum probability of each state considering all 
            previous observations.
        current_state: the state being transitioned to; the max state is the previous state that
            gives the highest probability for the current state
        transition_probabilities: dictionary of probabilities for moving from one state to another
        emission_probability: probability of the word associated with the given word_state_matrix
            occurring the current state
    Outputs:
        A pair: the first element is the max previous state given the current state and current 
        word, and the second element is the probability of the most optimal path to the max
        previous state considering all observations preceeding the previous observation
    """
    max_state = list(word_state_matrix.keys())[0]
    
    for state,probability in word_state_matrix.items():
        tag_bigram = (state, current_state)
        transition_probability = 0 if not tag_bigram in transition_probabilities else transition_probabilities[tag_bigram]
        state_conditional_probability = probability * transition_probability * emission_probability
        if state_conditional_probability > word_state_matrix[max_state]:
            max_state = state
            
    return (max_state, word_state_matrix[max_state])

# %%
def viterbi(observations, states, start_probabilities, transition_probabilities, emission_probabilities):
    """
    POS tagging for a single sentence using the viterbi algorithm.
    
    inputs:
        observations: list of word tokens, representing all words in a single sentence
        states: list of POS tags
        start_probabilities: probability of each state occurring at the start of a sentence
        transition_probabilities: dictionary of probabilities of one tag being preceeded by another; key
            is a pair of POS tags in the order being evaluated
        emission_probabilities: dictionary of probabilites of words being associated with a tag; key is
            a word/tag pair
    outputs:
        list of most likely POS tag for each observation
    """
    word_state_matrix = {}
    
    # Instantiate state values for the first word in the sentence
    word_state_matrix[observations[0]] = {}
    for state in states:
        word_tag_pair = (observations[0], state)
        start_probability = start_probabilities[(sentence_begin, state)]
        emission_probability = 0 if not word_tag_pair in emission_probabilities else emission_probabilities[word_tag_pair]
        word_state_matrix[observations[0]][state] = start_probability * emission_probability

    # For each observation/state pair, find the optimal path to that observation/state
    for observation_index in range(1, len(observations)):
        current_word = observations[observation_index]
        word_state_matrix[current_word] = {}
        previous_word = observations[observation_index - 1]
        for state in states:
            word_tag_pair = (current_word, state)
            emission_probability = 0 if not word_tag_pair in emission_probabilities else emission_probabilities[word_tag_pair]
            max_previous_state = maxState(word_state_matrix[previous_word], state, transition_probabilities, emission_probability)
            tag_bigram = (max_previous_state[0], state)
            transition_probability = 0 if not tag_bigram in transition_probabilities else transition_probabilities[tag_bigram]   
            word_state_matrix[current_word][state] = max_previous_state[1] * transition_probability * emission_probability

    # Backtrack through the word/state matrix, choosing the most optimal state for
    # each observation
    pos_tags = []
    for observation_index in range(len(observations)-1, -1, -1):
        current_word = observations[observation_index]
        current_word_state_matrix = word_state_matrix[current_word]
        best_tag_current_word = max(current_word_state_matrix, key=current_word_state_matrix.get)
        pos_tags.append(best_tag_current_word)
        
    return list(reversed(pos_tags))

# %%
# Create start probabilities matrix
start_probabilities = {}

for tag in tag_unigram_counts.keys():
    tag_bigram = (sentence_begin, tag)
    start_probability = 0 if not tag_bigram in transition_probabilities else transition_probabilities[tag_bigram]
    start_probabilities[tag_bigram] = start_probability

# %%
# Tag each sentence in the test data using the viterbi implementation and
# write results to output file
viterbi_out = os.path.join(os.getcwd(), 'Viterbi Output', 'POS_test_data_output.txt')

with open(viterbi_out, 'w') as file:
    for sentence_id, sentence in test_data_sentences.items():
        observations = sentence.split()[1:-1]
        pos_tags = viterbi(observations, tag_unigram_counts.keys(), start_probabilities, transition_probabilities, emission_probabilities)
        sentence_id_tag = '<sentence ID=' + str(sentence_id) + '>\n'
        file.write(sentence_id_tag)
        for index in range(0, len(pos_tags)):
            line = str(observations[index]) + ',' + str(pos_tags[index]) + '\n'
            file.write(line)
        file.write(sentence_end + '\n')
